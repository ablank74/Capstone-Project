# %% [markdown]
# Here we will work on gathering the data using the Jira API to build our CSV with a larger dataset

# %%
import requests
import json
import pandas as pd
from tqdm import tqdm
import os
from dotenv import load_dotenv  # Add python-dotenv for better env management

load_dotenv()
BEARER_TOKEN = os.getenv('JIRA_BEARER_TOKEN')
JIRA_URL = 'https://csc.cioxhealth.com'
 
session = requests.Session()
session.headers.update({
    'Authorization': f'Bearer {BEARER_TOKEN}',
    'Content-Type': 'application/json'  # Ensure Content-Type is set to application/json
    })

def login_to_jira():
    response = session.get(JIRA_URL + '/rest/api/2/user?username=SVC_IT_Automation')
    
    if response.status_code == 200:
        print("Successfully logged in to Jira")
        #print(response.json())
        return True
    else:
        print("Failed to log in to Jira")
        print(response.status_code, response.text)
        return False


# Login to JIRA
if not login_to_jira():
    raise Exception("Failed to log in to JIRA")
# Out:
# Successfully logged in to Jira

# %%
# Data retrieval variables
start_at = 0
max_results = 100
total = None
fields = ['key', 'project', 'summary', 'description', 'assignee', 'httpUrl', 'customfield_19900', 'customfield_15404', 'customfield_14201']
issues_list = []

# Prepare for progress bar
pbar = tqdm(total=None)  # Total will be updated after first response

# Main loop for data retrieval
while total is None or start_at < total:
    search_data = {
        'jql': "project='29-IT Service Desk' AND status=closed AND created >= startOfYear(-1y)",
        'fields': fields,
        'startAt': start_at,
        'maxResults': max_results
    }

    search_response = session.post(
        f"{JIRA_URL}/rest/api/2/search",
        data=json.dumps(search_data),
        timeout=300
    )

    if search_response.status_code == 200:
        search_result = search_response.json()
        if 'issues' in search_result:
            issues_list.extend(search_result['issues'])

        if total is None:
            total = search_result['total']
            pbar.total = total // max_results + (total % max_results > 0)
            pbar.refresh()

        start_at += max_results
        pbar.update(1)

    elif search_response.status_code == 401:
        if not login_to_jira():
            print("Failed to re-authenticate.")
            break

    else:
        print("Received unexpected status code:", search_response.status_code)
        print(search_response.text)
        break

pbar.close()

# Convert collected data to DataFrame
df = pd.json_normalize(issues_list)

# %% [markdown]
# We'll save the dataframe to a CSV so that we have a saved copy incase something happens so we don't have to redownload it again.

# %%
import datetime

# Save DataFrame to CSV
now = datetime.datetime.now()
df.to_csv(f'dataframe{now:%Y-%m-%d_%H-%M}.csv', index=False)

# %% [markdown]
# Lets look at the size and a sample of our dataframe we'll be working with

# %%
size = len(df)
print(f"Dataframe Size: {size:.2f}KB")

print(df.columns)
print(df.sample(5))

# %% [markdown]
# Verify GPU

# %%
import torch

# Check if CUDA is available
if torch.cuda.is_available():
    # Set device to the first CUDA device
    device = torch.device("cuda:0")
    print(f"Using device: {torch.cuda.get_device_name(0)}")

    # Create random tensors
    x = torch.randn(5000, 5000, device=device)
    y = torch.randn(5000, 5000, device=device)

    # Perform matrix multiplication
    print("Performing matrix multiplication on GPU...")
    z = torch.matmul(x, y)

    # The operation is performed on the GPU, so if this script runs without errors
    # and you observe the GPU utilization go up in your system's resource monitor,
    # then the Nvidia A1000 is being used.
    print("Done with matrix multiplication.")

else:
    print("CUDA is not available. Using CPU instead.")
# Out:
# Using device: NVIDIA GeForce RTX 3090
# Performing matrix multiplication on GPU...
# Done with matrix multiplication.

# %% [markdown]
# This cell is used to reload the dataframe from the CSV

# %%
import pandas as pd
# Load CSV
df = pd.read_csv('dataframe2.csv')
print(len(df),'rows')
# Out:
# 322600 rows

# %%
# Remove unneeded columns
df = df[[
    'fields.customfield_14201',
    'fields.assignee.displayName',
    'fields.customfield_15404.value',
    'fields.summary',
    'fields.description'
]]

# %% [markdown]
# We need to rename the columns to make it more easily understandable

# %% [markdown]
# Rename columns

# %%
df = df.rename(columns={
    'fields.customfield_14201':'Category 1',
    'fields.assignee.displayName':'Assignee',
    'fields.customfield_15404.value':'IT Group',
    'fields.summary':'Summary',
    'fields.description':'Description'
})

# %% [markdown]
# Data Cleaning

# %%
import nltk
from nltk.corpus import stopwords
import re

# Download only stopwords if needed
nltk.download('stopwords')

def clean_text(text):
    if not isinstance(text, str):
        return ''
    
    # Convert to lowercase
    text = text.lower()
    
    # Remove special characters and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    
    # Remove extra whitespace
    text = ' '.join(text.split())
    
    # Remove stopwords - using simple split() instead of word_tokenize
    stop_words = set(stopwords.words('english'))
    words = text.split()
    text = ' '.join([w for w in words if w not in stop_words])
    
    return text

# Clean Summary and Description fields
df['Summary'] = df['Summary'].apply(clean_text)
df['Description'] = df['Description'].apply(clean_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(df.columns)
print(df.sample(5))
# Out:
# Index(['Category 1', 'Assignee', 'IT Group', 'Summary', 'Description'], dtype='object')
#                                                Category 1           Assignee  \
# 92188   [{'self': 'https://csc.cioxhealth.com/rest/api...  Ronald Montesanto
# 183578  [{'self': 'https://csc.cioxhealth.com/rest/api...  SVC_IT_Automation
# 304018  [{'self': 'https://csc.cioxhealth.com/rest/api...  Nichole McPherson
# 292838  [{'self': 'https://csc.cioxhealth.com/rest/api...  Nichole McPherson
# 16501   [{'self': 'https://csc.cioxhealth.com/rest/api...        Thomas Ware
#
#                     IT Group                           Summary  \
# 92188                   ITSD      request backoffice bi report
# 183578                   NaN  healthsource site access request
# 304018  Product Support (PS)   healthsource request stuck read
# 292838  Product Support (PS)          healthsource qc progress
# 16501                    DTO            cutepdf need uninstall
#
#                                               Description
# 92188   eid completed still bi report requests needs c...
# 183578
# 304018                            erequest stuck read eid
# 292838  known issue request staying qc process longer ...
# 16501   description user calling due needing cutepdf u...

# %% [markdown]
# This is to clean up the code, removing all NaN rows as well as all ITSD rows so only properly assigned tickets are in place.

# %%
#drop all rows with IT Group = NaN
df = df.dropna(subset=['IT Group'])

#drop all ITSD tickets
df = df[df['IT Group'] != 'ITSD']

# %%
df['IT Group'].unique()
# Out:
# array(['DCO', 'DTO', 'HealthSource CX', 'App- Corp Systems', 'App- CDAI',
#        'Privacy Hub', 'App- CRI', 'ReChase', 'SOC', 'Request Fulfillment',
#        'Digital Grid', 'M365', 'Telecom', 'Enterprise Tools', 'EUS',
#        'BI Reporting CDAI', 'ARCH', 'NETWORK', 'IT Software Licensing',
#        'Business Intelligence CRI', 'Healthsource', 'Virtualization',
#        'CorpSys - Coupa', 'IAM', 'DBA', 'App-SmartRequest/Record Hub',
#        'Automation (RPA)', 'Infra Engineering', 'CorpSys - NetSuite',
#        'Desktop Engineering', 'HCM', 'Product Support (PS)', 'Salesforce',
#        'Red Team', 'Healthcare Integration', 'EDELIVERY',
#        'App-Arch Support', 'Print Eng', 'PMO', 'CRS'], dtype=object)

# %% [markdown]
# Analyze Class Distribution

# %%
# Analyze class distribution
print("Class distribution:")
print(df['IT Group'].value_counts())
print("\nPercentage distribution:")
print(df['IT Group'].value_counts(normalize=True) * 100)

# Visualize the distribution
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 6))
df['IT Group'].value_counts().plot(kind='bar')
plt.title('Distribution of IT Groups')
plt.xlabel('IT Group')
plt.ylabel('Number of Tickets')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Class distribution:
# IT Group
# Product Support (PS)           34759
# DTO                            29942
# DCO                            18326
# Request Fulfillment            16842
# App- Corp Systems               8997
# App- CDAI                       8326
# HealthSource CX                 6691
# ReChase                         5368
# App- CRI                        4787
# M365                            4224
# Digital Grid                    2529
# Telecom                         2412
# SOC                             1792
# IAM                             1617
# IT Software Licensing           1349
# NETWORK                         1259
# EUS                              896
# Enterprise Tools                 860
# BI Reporting CDAI                821
# App-SmartRequest/Record Hub      631
# Virtualization                   623
# DBA                              600
# Infra Engineering                480
# Business Intelligence CRI        441
# Desktop Engineering              150
# Healthcare Integration           122
# CorpSys - Coupa                  118
# App-Arch Support                 104
# Healthsource                      47
# EDELIVERY                         34
# CorpSys - NetSuite                23
# Red Team                          21
# ARCH                               8
# CRS                                6
# Print Eng                          3
# Automation (RPA)                   3
# Privacy Hub                        2
# PMO                                2
# HCM                                1
# Salesforce                         1
# Name: count, dtype: int64
#
# Percentage distribution:
# IT Group
# Product Support (PS)           22.393810
# DTO                            19.290413
# DCO                            11.806696
# Request Fulfillment            10.850616
# App- Corp Systems               5.796401
# App- CDAI                       5.364103
# HealthSource CX                 4.310739
# ReChase                         3.458384
# App- CRI                        3.084069
# M365                            2.721351
# Digital Grid                    1.629332
# Telecom                         1.553953
# SOC                             1.154513
# IAM                             1.041767
# IT Software Licensing           0.869106
# NETWORK                         0.811122
# EUS                             0.577256
# Enterprise Tools                0.554063
# BI Reporting CDAI               0.528937
# App-SmartRequest/Record Hub     0.406528
# Virtualization                  0.401374
# DBA                             0.386556
# Infra Engineering               0.309244
# Business Intelligence CRI       0.284118
# Desktop Engineering             0.096639
# Healthcare Integration          0.078600
# CorpSys - Coupa                 0.076023
# App-Arch Support                0.067003
# Healthsource                    0.030280
# EDELIVERY                       0.021905
# CorpSys - NetSuite              0.014818
# Red Team                        0.013529
# ARCH                            0.005154
# CRS                             0.003866
# Print Eng                       0.001933
# Automation (RPA)                0.001933
# Privacy Hub                     0.001289
# PMO                             0.001289
# HCM                             0.000644
# Salesforce                      0.000644
# Name: proportion, dtype: float64

# %% [markdown]
# Lets normalize the data so that the classes are more balanced

# %%
print("\nCreating balanced dataset for baseline model...")
group_counts = df['IT Group'].value_counts()
min_acceptable_samples = 500
print(f"\nOriginal class distribution:")
print(group_counts)

valid_groups = group_counts[group_counts >= min_acceptable_samples].index
df_filtered = df[df['IT Group'].isin(valid_groups)]
print(f"\nRemoved {len(group_counts) - len(valid_groups)} classes with fewer than {min_acceptable_samples} samples")

balanced_dfs = []
samples_per_class = min_acceptable_samples
for group in valid_groups:
    group_df = df_filtered[df_filtered['IT Group'] == group]
    if len(group_df) < samples_per_class * 1.5:
        n_samples = int(len(group_df) * 0.8)
    else:
        n_samples = samples_per_class
    sampled_df = group_df.sample(n=n_samples, random_state=42)
    balanced_dfs.append(sampled_df)

df_balanced = pd.concat(balanced_dfs, ignore_index=True)

print("\nFinal balanced dataset statistics:")
print(f"Total samples: {len(df_balanced)}")
print("\nSamples per class:")
print(df_balanced['IT Group'].value_counts())

df = df_balanced
df = df.sample(frac=1, random_state=42).reset_index(drop=True)
# Out:
# Creating balanced dataset for baseline model...
#
# Original class distribution:
# IT Group
# Product Support (PS)           34759
# DTO                            29942
# DCO                            18326
# Request Fulfillment            16842
# App- Corp Systems               8997
# App- CDAI                       8326
# HealthSource CX                 6691
# ReChase                         5368
# App- CRI                        4787
# M365                            4224
# Digital Grid                    2529
# Telecom                         2412
# SOC                             1792
# IAM                             1617
# IT Software Licensing           1349
# NETWORK                         1259
# EUS                              896
# Enterprise Tools                 860
# BI Reporting CDAI                821
# App-SmartRequest/Record Hub      631
# Virtualization                   623
# DBA                              600
# Infra Engineering                480
# Business Intelligence CRI        441
# Desktop Engineering              150
# Healthcare Integration           122
# CorpSys - Coupa                  118
# App-Arch Support                 104
# Healthsource                      47
# EDELIVERY                         34
# CorpSys - NetSuite                23
# Red Team                          21
# ARCH                               8
# CRS                                6
# Print Eng                          3
# Automation (RPA)                   3
# Privacy Hub                        2
# PMO                                2
# HCM                                1
# Salesforce                         1
# Name: count, dtype: int64
#
# Removed 18 classes with fewer than 500 samples
#
# Final balanced dataset statistics:
# Total samples: 10982
#
# Samples per class:
# IT Group
# App-SmartRequest/Record Hub    504
# Product Support (PS)           500
# DCO                            500
# Request Fulfillment            500
# App- Corp Systems              500
# DTO                            500
# App- CDAI                      500
# HealthSource CX                500
# App- CRI                       500
# ReChase                        500
# Digital Grid                   500
# Telecom                        500
# SOC                            500
# M365                           500
# IAM                            500
# IT Software Licensing          500
# EUS                            500
# NETWORK                        500
# Enterprise Tools               500
# BI Reporting CDAI              500
# Virtualization                 498
# DBA                            480
# Name: count, dtype: int64

# %% [markdown]
# Now we start our work.  We load the dataframe from the CSV, and we'll start filling in empty fields to prevent errors

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
import gc

# Combine 'Summary', 'Description', and 'Last Comment Assignee' into one field
#df['combined'] = df[['Summary', 'Description', 'Last Comment Assignee']].fillna('').agg(' '.join, axis=1)
df['combined'] = df[['Summary', 'Description']].fillna('').agg(' '.join, axis=1)

# Drop the original fields
#df = df.drop(['Summary', 'Description', 'Last Comment Assignee'], axis=1)
#df = df.drop(['Summary', 'Description'], axis=1)

# Fill in the blank values in 'IT Group', 'Assignee', 'Category 1', 'Category 2', and 'Category 3'
imputer = SimpleImputer(strategy='constant', fill_value='unknown')
#df[['IT Group', 'Assignee', 'Category 1', 'Category 2', 'Category 3']] = imputer.fit_transform(df[['IT Group', 'Assignee', 'Category 1', 'Category 2', 'Category 3']])
df[['IT Group', 'Assignee', 'Category 1']] = imputer.fit_transform(df[['IT Group', 'Assignee', 'Category 1']])

# %%
import gc
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer

# Convert data types for memory efficiency
# df = df.astype({'col_name': 'category', 'int_col': 'int32', ...})



# Create and fit label encoders
le_it_group = LabelEncoder()
#le_assignee = LabelEncoder()
df['IT Group'] = le_it_group.fit_transform(df['IT Group'])
#df['Assignee'] = le_assignee.fit_transform(df['Assignee'])
print("Label Encoders Completed")

# Drop original columns if they are no longer needed
#df.drop(['IT Group', 'Assignee'], axis=1, inplace=True)

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(df['combined'], df[['IT Group', 'Assignee']], test_size=0.2, random_state=42)
print("Train/Test split completed")

# Create a pipeline for each category
pipeline_it_group = Pipeline([('tfidf', TfidfVectorizer(max_features=10000)), ('clf', RandomForestClassifier(n_jobs=-1))])
#pipeline_assignee = Pipeline([('tfidf', TfidfVectorizer(max_features=10000)), ('clf', RandomForestClassifier(n_jobs=-1))])
print("Pipelines created")

# Train the models
pipeline_it_group.fit(X_train, y_train['IT Group'])
#pipeline_assignee.fit(X_train, y_train['Assignee'])
print("Training Completed")

# Clear memory
gc.collect()
# Out:
# Label Encoders Completed
# Train/Test split completed
# Pipelines created
# Training Completed
# 8918

# %% [markdown]
# Creates a grid search to find the best parameters for the model

# %%
from sklearn.model_selection import GridSearchCV

# Keep our existing TF-IDF vectorizer
tfidf = TfidfVectorizer(
    max_features=15000,
    ngram_range=(1, 3),
    min_df=2,
    max_df=0.95,
    strip_accents='unicode',
    sublinear_tf=True
)

# Create base pipeline
base_pipeline = Pipeline([
    ('tfidf', tfidf),
    ('clf', RandomForestClassifier(
        n_jobs=-1,
        class_weight='balanced',
        random_state=42  # Add for reproducibility
    ))
])

# Expanded parameter grid
param_grid = {
    'clf__n_estimators': [200, 300, 400],
    'clf__max_depth': [20, 30, 40],
    'clf__min_samples_split': [2, 5],
    'clf__min_samples_leaf': [1, 2],
    'clf__max_features': ['sqrt', 'log2'],  # Add feature selection strategy
    'clf__bootstrap': [True, False]  # Add bootstrap sampling option
}

# Create and train grid search
grid_search = GridSearchCV(
    base_pipeline,
    param_grid,
    cv=3,
    n_jobs=-1,
    verbose=2,
    scoring='accuracy'  # Explicitly set scoring metric
)

print("Starting grid search...")
grid_search.fit(X_train, y_train['IT Group'])

print("\nBest parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)

# Use the best model
pipeline_it_group = grid_search.best_estimator_
# Out:
# Starting grid search...
# Fitting 3 folds for each of 144 candidates, totalling 432 fits
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2881: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best parameters: {'clf__bootstrap': True, 'clf__max_depth': 40, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 2, 'clf__n_estimators': 400}
# Best cross-validation score: 0.7056341304000382

# %% [markdown]
# # RoBERTa Implementation
# Here we'll implement RoBERTa as an alternative model for comparison with RandomForest and XGBoost.
# We'll use the transformers library to load and fine-tune RoBERTa on our ticket classification task.

# %%
from transformers import RobertaTokenizer, RobertaForSequenceClassification, AdamW
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
import tqdm as notebook_tqdm

# Initialize tokenizer and model
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
model = RobertaForSequenceClassification.from_pretrained(
    'roberta-base',
    num_labels=len(le_it_group.classes_),  # Number of IT groups
    output_attentions=False,
    output_hidden_states=False,
)

# Move model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# Create dataset class
class TicketDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_length=512):
        self.encodings = tokenizer(texts, truncation=True, padding=True, 
                                 max_length=max_length, return_tensors='pt')
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: val[idx] for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# Prepare data
train_texts = X_train.tolist()
train_labels = y_train['IT Group'].tolist()  # Using encoded labels

# Create datasets
train_dataset = TicketDataset(train_texts, train_labels, tokenizer)
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)

# Training configuration
optimizer = AdamW(model.parameters(), lr=2e-5)
epochs = 3

# Training loop
model.train()
for epoch in range(epochs):
    total_loss = 0
    progress_bar = tqdm(train_loader, desc=f'Epoch {epoch + 1}')
    
    for batch in progress_bar:
        optimizer.zero_grad()
        
        # Move batch to GPU
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)
        
        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        progress_bar.set_postfix({'loss': f'{loss.item():.3f}'})
    
    avg_loss = total_loss / len(train_loader)
    print(f'\nEpoch {epoch + 1} average loss: {avg_loss:.3f}')

# Add prediction function for RoBERTa
def predict_with_roberta(text):
    model.eval()
    with torch.no_grad():
        inputs = tokenizer(text, return_tensors='pt', truncation=True, max_length=512)
        inputs = {k: v.to(device) for k, v in inputs.items()}
        
        outputs = model(**inputs)
        probs = F.softmax(outputs.logits, dim=-1)
        
        predicted_class = torch.argmax(probs, dim=-1).cpu().numpy()[0]
        confidence_score = probs.max().item()
        
        predicted_group = le_it_group.inverse_transform([predicted_class])[0]
        
        return predicted_group, confidence_score

# Save the model
model_name = 'roberta_classifier'
model_path = f'{model_name}_model.pth'
torch.save(model.state_dict(), model_path)
print(f"Saved {model_name} model to {model_path}")

# %% [markdown]
# Evaluate the RoBERTa Model

# %%
# Evaluation of RoBERTa Model
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

def evaluate_roberta():
    """
    Evaluate RoBERTa model performance on test set
    """
    model.eval()  # Set model to evaluation mode
    predictions = []
    true_labels = []
    confidence_scores = []
    
    # Create test dataset
    test_texts = X_test.tolist()
    test_labels = y_test['IT Group'].tolist()
    
    print("Evaluating RoBERTa model...")
    
    # Get predictions for test set
    with torch.no_grad():  # No gradients needed for evaluation
        for text, true_label in tqdm(zip(test_texts, test_labels), total=len(test_texts)):
            # Get prediction
            inputs = tokenizer(text, return_tensors='pt', truncation=True, max_length=512)
            inputs = {k: v.to(device) for k, v in inputs.items()}
            
            outputs = model(**inputs)
            probs = F.softmax(outputs.logits, dim=-1)
            
            predicted_class = torch.argmax(probs, dim=-1).cpu().numpy()[0]
            confidence = probs.max().item()
            
            predictions.append(predicted_class)
            true_labels.append(true_label)
            confidence_scores.append(confidence)
    
    # Convert predictions back to group names
    predicted_groups = le_it_group.inverse_transform(predictions)
    true_groups = le_it_group.inverse_transform(true_labels)
    
    # Calculate metrics
    accuracy = accuracy_score(true_groups, predicted_groups)
    class_report = classification_report(true_groups, predicted_groups)
    conf_matrix = confusion_matrix(true_groups, predicted_groups)
    
    # Print results
    print("\nRoBERTa Model Evaluation Results:")
    print(f"Overall Accuracy: {accuracy:.4f}")
    print("\nClassification Report:")
    print(class_report)
    
    # Plot confusion matrix
    plt.figure(figsize=(15, 10))
    sns.heatmap(conf_matrix, 
                annot=True, 
                fmt='d',
                xticklabels=le_it_group.classes_,
                yticklabels=le_it_group.classes_)
    plt.title('RoBERTa Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()
    
    # Analyze confidence distribution
    plt.figure(figsize=(10, 6))
    plt.hist(confidence_scores, bins=50)
    plt.title('Distribution of Confidence Scores')
    plt.xlabel('Confidence Score')
    plt.ylabel('Count')
    plt.show()
    
    # Analyze accuracy vs confidence
    confidence_bins = np.linspace(0, 1, 11)
    accuracies = []
    counts = []
    
    for i in range(len(confidence_bins)-1):
        mask = (np.array(confidence_scores) >= confidence_bins[i]) & (np.array(confidence_scores) < confidence_bins[i+1])
        if mask.sum() > 0:
            bin_acc = accuracy_score(np.array(true_groups)[mask], np.array(predicted_groups)[mask])
            accuracies.append(bin_acc)
            counts.append(mask.sum())
        else:
            accuracies.append(0)
            counts.append(0)
    
    plt.figure(figsize=(10, 6))
    plt.bar(confidence_bins[:-1], accuracies, width=0.1)
    plt.title('Accuracy vs Confidence')
    plt.xlabel('Confidence Score')
    plt.ylabel('Accuracy')
    plt.show()
    
    # Compare with Random Forest accuracy
    rf_predictions = pipeline_it_group.predict(X_test)
    rf_accuracy = accuracy_score(y_test['IT Group'], rf_predictions)
    
    print("\nModel Comparison:")
    print(f"RoBERTa Accuracy: {accuracy:.4f}")
    print(f"Random Forest Accuracy: {rf_accuracy:.4f}")
    
    # Return metrics for further analysis if needed
    return {
        'accuracy': accuracy,
        'classification_report': class_report,
        'confusion_matrix': conf_matrix,
        'confidence_scores': confidence_scores,
        'predictions': predicted_groups,
        'true_labels': true_groups
    }

# Run evaluation
evaluation_results = evaluate_roberta()

# Additional analysis: Most common misclassifications
def analyze_misclassifications(true_labels, predictions, top_n=10):
    """
    Analyze the most common misclassifications
    """
    misclassifications = []
    for true, pred in zip(true_labels, predictions):
        if true != pred:
            misclassifications.append((true, pred))
    
    # Count misclassification patterns
    from collections import Counter
    misclass_counts = Counter(misclassifications)
    
    print("\nTop misclassification patterns:")
    for (true, pred), count in misclass_counts.most_common(top_n):
        print(f"True: {true:<20} Predicted: {pred:<20} Count: {count}")

# Analyze misclassifications
analyze_misclassifications(evaluation_results['true_labels'], 
                         evaluation_results['predictions'])

# %% [markdown]
# This section onward uses the model to predict the IT Group for a ticket in Jira.

# %% [markdown]
# First we create a function to search for a ticket in Jira and return the IT Group

# %%
def search_jira_ticket(ticket_number):
    if not login_to_jira():
        raise Exception("Failed to log in to JIRA")

    search_data = {
        'jql': f"issue = {ticket_number}",
        'fields': ['summary', 'description', 'assignee', 'customfield_19900', 'customfield_15404', 'customfield_14201'],
        'startAt': 0,
        'maxResults': 1
    }

    search_response = session.post(
        f"{JIRA_URL}/rest/api/2/search",
        data=json.dumps(search_data),
        timeout=300
    )

    if search_response.status_code == 200:
        search_result = search_response.json()
        return pd.json_normalize(search_result['issues'])
    else:
        print("Failed to retrieve the ticket:", search_response.status_code)
        print(search_response.text)
        return None

# %% [markdown]
# Here is the function to validate and suggest the IT Group for a ticket in Jira.

# %%
def search_jira_unassigned_tickets_in_group(group_name):
 if not login_to_jira():
     raise Exception("Failed to log in to JIRA")
   
       # Modify the JQL query
       search_data = {
           'jql': f"project='29-IT Service Desk' AND 'IT Group' = '{group_name}' AND status != closed",
           'fields': ['key', 'summary', 'description', 'assignee', 'customfield_19900', 'customfield_15404', 'customfield_14201'],
           'startAt': 0,
           'maxResults': 100  # You can adjust the maxResults as needed
       }
   
       search_response = session.post(
           f"{JIRA_URL}/rest/api/2/search",
           data=json.dumps(search_data),
           timeout=300
       )
   
       if search_response.status_code == 200:
           search_result = search_response.json()
           #return pd.json_normalize(search_result['issues'])
       else:
           print("Failed to retrieve tickets:", search_response.status_code)
           print(search_response.text)
           return None
   
   # Example usage
group_name = "M365"
unassigned_tickets_df = search_jira_unassigned_tickets_in_group(group_name)
print(unassigned_tickets_df)
# Out:
#   File <tokenize>:28
#     group_name = "M365"
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
def validate_and_suggest_it_group_with_confidence(group_name, confidence_threshold=0.10):
    df_tickets = search_jira_unassigned_tickets_in_group(group_name)
    if df_tickets.empty:
        return "No tickets found or error in retrieval"

    # Create a copy of the dataframe to avoid the warning
    df_tickets = df_tickets.copy()
    
    # Fix the fillna operations
    df_tickets['fields.summary'] = df_tickets['fields.summary'].fillna('')
    df_tickets['fields.description'] = df_tickets['fields.description'].fillna('')

    # Combine fields
    combined_fields = df_tickets['fields.summary'] + ' ' + df_tickets['fields.description']

    try:
        # Get Predicted Probabilities
        predicted_probs = pipeline_it_group.predict_proba(combined_fields)
        predicted_groups_encoded = pipeline_it_group.predict(combined_fields)
        predicted_groups = le_it_group.inverse_transform(predicted_groups_encoded)

        # Extract the highest probability as the confidence score
        confidence_scores = predicted_probs.max(axis=1)

        # Base URL for JIRA tickets
        jira_ticket_base_url = "https://csc.cioxhealth.com/browse/"

        # Compare, Suggest and Include Confidence Score and URL
        suggestions = []
        for index, row in df_tickets.iterrows():
            predicted_group = predicted_groups[index]
            confidence_score = confidence_scores[index]

            # Create a URL to the ticket
            ticket_url = jira_ticket_base_url + row['key']

            # Only suggest reassignment if confidence is greater than the threshold
            if confidence_score > confidence_threshold and predicted_group != group_name:
                suggestions.append({
                    'Ticket': f"[{row['key']}]({ticket_url})",
                    'Current Group': group_name,
                    'Suggested Group': predicted_group,
                    'Confidence Score': confidence_score
                })

        # Sort suggestions by confidence score in descending order
        sorted_suggestions = sorted(suggestions, key=lambda x: x['Confidence Score'], reverse=True)
        
        if not sorted_suggestions:
            return f"No suggestions found for group {group_name} (all tickets are correctly assigned or below confidence threshold)"
            
        return sorted_suggestions
    
    except Exception as e:
        return f"Error processing tickets: {str(e)}"

# Example usage
group_name = "M365"
suggestions = validate_and_suggest_it_group_with_confidence(group_name)

if isinstance(suggestions, list):
    print("Suggestions for reassignment with confidence scores and links to JIRA, sorted by confidence:")
    for suggestion in suggestions:
        print(f"Ticket {suggestion['Ticket']} should be in '{suggestion['Suggested Group']}' instead of '{suggestion['Current Group']}' with confidence score: {suggestion['Confidence Score']:.2f}")
else:
    print(suggestions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 59
#      57 # Example usage
#      58 group_name = "M365"
# ---> 59 suggestions = validate_and_suggest_it_group_with_confidence(group_name)
#      61 if isinstance(suggestions, list):
#      62     print("Suggestions for reassignment with confidence scores and links to JIRA, sorted by confidence:")
#
# Cell In[17], line 2, in validate_and_suggest_it_group_with_confidence(group_name, confidence_threshold)
#       1 def validate_and_suggest_it_group_with_confidence(group_name, confidence_threshold=0.10):
# ----> 2     df_tickets = search_jira_unassigned_tickets_in_group(group_name)
#       3     if df_tickets.empty:
#       4         return "No tickets found or error in retrieval"
#
# NameError: name 'search_jira_unassigned_tickets_in_group' is not defined
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=   7.0s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=   9.1s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=   5.8s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   2.6s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=  14.5s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   7.3s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=   7.9s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=   4.8s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=  15.2s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   7.7s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  13.9s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   4.2s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=  12.7s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=  10.0s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=   6.4s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   3.3s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=  19.5s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=  12.3s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=  10.9s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=   5.7s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   3.7s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=  24.4s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=  13.2s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=  11.6s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=  13.1s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  16.1s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=   5.7s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   3.4s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=  15.9s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   7.6s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=   7.5s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   3.8s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=  17.4s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   9.4s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=  12.0s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  24.3s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=   6.6s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   3.1s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=  15.3s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=  15.2s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  18.0s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   4.7s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=  17.1s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=  17.2s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  26.9s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=   7.4s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=   9.5s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=   4.8s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   2.1s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  22.1s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=   9.3s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=   4.5s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=  17.0s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   8.4s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=  11.5s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   4.1s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=  13.0s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   8.4s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=   7.3s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   2.6s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=  16.4s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=  13.8s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  17.7s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   2.8s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  56.3s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=   8.9s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=   8.8s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=   8.1s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=   4.9s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   3.3s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=  15.9s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   7.5s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=   8.4s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  15.6s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=  11.0s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=   7.6s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=   7.5s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  24.2s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=   5.0s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=   3.2s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=  13.3s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=  12.4s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=  16.4s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=   9.5s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=  10.5s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=  17.0s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=  13.4s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=  15.2s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=   9.0s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  11.5s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   6.5s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=   4.9s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  12.4s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=  10.3s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  10.0s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   3.0s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=  13.8s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=  10.3s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  15.6s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  20.4s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=   9.0s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=   3.1s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  39.9s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=  10.8s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  26.0s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=  12.1s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  28.2s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=   9.6s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   6.8s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=   4.1s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=   3.2s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=   8.0s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=  11.1s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   8.0s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=   5.8s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   4.1s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=  13.0s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   8.8s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  15.3s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  14.3s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=  10.4s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=   7.2s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  20.6s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=  11.2s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  15.7s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=   4.7s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  43.1s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=  14.4s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=   9.0s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  15.7s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=   4.1s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=   5.3s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=  14.7s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   7.6s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=   7.0s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=   4.0s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  25.6s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=  11.1s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   4.1s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  24.4s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=   7.2s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  35.6s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=  13.0s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   2.8s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  52.0s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=   8.8s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   5.5s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=   8.9s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=   8.8s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=   4.4s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   3.8s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=  16.7s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   7.2s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=   5.9s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   3.7s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=  15.4s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   8.7s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=   6.0s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=   7.9s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   3.9s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=  12.5s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   7.9s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=   6.8s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   2.4s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  47.0s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=   5.3s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=  17.2s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=  16.4s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  22.3s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=   9.6s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=   9.0s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   6.8s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=   5.5s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   2.1s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  22.7s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  10.9s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  19.2s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   7.1s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=   7.1s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=   7.7s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  19.8s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   9.5s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=   3.4s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  34.0s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=  11.6s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=   5.4s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  32.2s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=  15.4s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=  14.9s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   4.3s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=   7.0s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=   8.9s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=   5.6s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   2.1s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=  10.6s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=  11.1s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=   9.4s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=   3.5s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=  13.3s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=  10.9s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  15.4s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  18.2s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   7.4s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=   7.1s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  32.6s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  17.9s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   4.4s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=  17.1s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=  16.2s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  22.7s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   7.1s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  15.1s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=   5.2s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=   2.7s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  17.0s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   8.1s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=   7.1s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   3.1s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=  13.9s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=   9.9s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  14.3s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   4.8s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=  15.4s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=  10.0s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=   4.7s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=  13.6s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=  14.5s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=  11.8s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=  10.8s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  38.7s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  28.1s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  13.8s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   6.4s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=   2.6s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  15.3s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=  10.8s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=   8.5s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  23.0s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  12.1s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=   7.4s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=  11.8s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=   9.3s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=   6.3s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=   2.7s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  24.6s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=  14.1s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=  12.0s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   3.5s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=  23.9s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=  12.7s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  28.1s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=  10.3s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   5.6s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=   5.5s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=   3.2s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=  13.1s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=  10.8s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=   7.3s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   2.7s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  26.9s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=  12.5s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  12.2s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=   9.6s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=   7.6s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=   2.6s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   3.0s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=  19.5s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=  12.3s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=  10.8s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=   6.4s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  31.8s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=  16.5s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=  14.5s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   4.5s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=   7.2s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=   8.9s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=   6.2s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   3.9s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=  13.1s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   6.1s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  10.4s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   3.4s
# ...
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=  11.5s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  18.3s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   3.6s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=  22.3s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=  12.4s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  22.8s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=   7.8s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=  10.4s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   6.4s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=   4.4s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=   3.5s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=  15.2s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   9.1s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=   8.2s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  20.5s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=  10.5s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=   8.2s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   4.4s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=  13.6s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   8.8s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=   6.5s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   3.6s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=  15.8s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=  14.4s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  17.7s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   3.4s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=  25.1s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=  13.2s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=  13.5s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=   8.7s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   4.1s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  11.7s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   6.5s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=   5.1s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  20.4s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=   8.4s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=   4.7s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  16.6s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=  11.0s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=  10.4s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=   6.6s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=  11.2s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=  10.3s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=   5.3s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=   3.2s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=  13.7s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=  14.7s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  16.7s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=   5.7s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  40.8s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=  13.2s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=   8.8s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   4.4s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  14.3s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   6.0s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=   3.0s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  19.9s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=   7.9s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=   5.5s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   3.8s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=  12.7s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=  11.0s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=  11.3s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   4.0s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=  11.2s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=  10.9s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=   7.1s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=200; total time=   2.2s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  47.1s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=   5.4s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=  19.4s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=  16.8s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=300; total time=  27.0s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   3.2s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=   6.3s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=   8.4s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=   5.3s
# [CV] END clf__bootstrap=True, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=   2.5s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  12.9s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=  10.3s
# [CV] END clf__bootstrap=True, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  11.0s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  12.6s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=200; total time=  11.7s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  13.0s
# [CV] END clf__bootstrap=True, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=400; total time=   6.8s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=400; total time=  14.2s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=   7.5s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=200; total time=   4.7s
# [CV] END clf__bootstrap=False, clf__max_depth=20, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=   2.6s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=200; total time=  23.0s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=sqrt, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=300; total time=  12.2s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=1, clf__min_samples_split=5, clf__n_estimators=300; total time=  11.9s
# [CV] END clf__bootstrap=False, clf__max_depth=30, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=   5.3s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__min_samples_split=2, clf__n_estimators=400; total time=  54.2s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=2, clf__n_estimators=300; total time=   9.3s
# [CV] END clf__bootstrap=False, clf__max_depth=40, clf__max_features=log2, clf__min_samples_leaf=2, clf__min_samples_split=5, clf__n_estimators=400; total time=   3.9s

# %% [markdown]
# Updated to use RoBERTa and RandomForest to predict the IT Group for a ticket in Jira.

# %% [markdown]
# Load RoBERTa Model from disk

# %%
print("Loading saved model...")
model = RobertaForSequenceClassification.from_pretrained(
    'roberta-base',
    num_labels=len(le_it_group.classes_),
    output_attentions=False,
    output_hidden_states=False,
).to(device)
model.load_state_dict(torch.load(model_path))
print("Model loaded successfully")

# Verify the model is loaded correctly
print(f"Model type: {type(model)}")
print(f"Model device: {next(model.parameters()).device}")

# %%
# First, let's check if the model is properly initialized
print(f"Model type: {type(model)}")
print(f"Is model on correct device: {next(model.parameters()).device}")

def predict_with_roberta(text):
    """Make predictions using the RoBERTa model"""
    global model, tokenizer, device

    try:
        model.eval()
        with torch.no_grad():
            inputs = tokenizer(text, return_tensors='pt', truncation=True, max_length=512)
            inputs = {k: v.to(device) for k, v in inputs.items()}
            
            outputs = model(**inputs)
            probs = F.softmax(outputs.logits, dim=-1)
            
            predicted_class = torch.argmax(probs, dim=-1).cpu().numpy()[0]
            confidence_score = probs.max().item()
            
            predicted_group = le_it_group.inverse_transform([predicted_class])[0]
            
            return predicted_group, confidence_score
    except Exception as e:
        print(f"Detailed error in predict_with_roberta: {str(e)}")
        print(f"Model state: {model}")
        return None, 0.0

def validate_and_suggest_it_group_with_models(group_name, confidence_threshold=0.10):
    df_tickets = search_jira_unassigned_tickets_in_group(group_name)
    if df_tickets.empty:
        return "No tickets found or error in retrieval"

    suggestions = []
    print("\nAnalyzing predictions:")
    for index, row in df_tickets.iterrows():
        combined_text = f"{row['fields.summary']} {row['fields.description']}"
        ticket_url = f"https://csc.cioxhealth.com/browse/{row['key']}"
        
        # Get predictions from RandomForest and RoBERTa
        rf_pred_encoded = pipeline_it_group.predict([combined_text])[0]
        rf_pred = le_it_group.inverse_transform([rf_pred_encoded])[0]
        rf_prob = pipeline_it_group.predict_proba([combined_text]).max()
        
        roberta_result = predict_with_roberta(combined_text)
        if roberta_result[0] is None:
            continue
            
        roberta_pred, roberta_prob = roberta_result
        
        # Calculate average confidence
        avg_conf = (rf_prob + roberta_prob) / 2
        
        # Debug print for each ticket
        print(f"\nTicket {row['key']} - {ticket_url}")
        print(f"RandomForest: {rf_pred} (confidence: {rf_prob:.2f})")
        print(f"RoBERTa: {roberta_pred} (confidence: {roberta_prob:.2f})")
        print(f"Current Group: {group_name}")
        
        # Combine predictions
        predictions = {
            'RandomForest': (rf_pred, rf_prob),
            'RoBERTa': (roberta_pred, roberta_prob)
        }
        
        # Only suggest if both models agree on a different group
        if rf_pred == roberta_pred and rf_pred != group_name:
            if avg_conf > confidence_threshold:
                print("-> Models agree on different group")
                suggestions.append({
                    'Ticket': f"[{row['key']}](https://csc.cioxhealth.com/browse/{row['key']})",
                    'Current Group': group_name,
                    'Suggested Group': rf_pred,
                    'Confidence Score': avg_conf,
                    'Model Predictions': predictions
                })
            else:
                print(f"-> Models agree on different group but confidence ({avg_conf:.2f}) below threshold ({confidence_threshold})")
        else:
            if rf_pred != roberta_pred:
                print(f"-> Models disagree on prediction (avg confidence: {avg_conf:.2f})")
            else:
                print(f"-> Models agree on current group (avg confidence: {avg_conf:.2f})")
    
    return sorted(suggestions, key=lambda x: x['Confidence Score'], reverse=True)

# Example usage
group_name = "M365"
suggestions = validate_and_suggest_it_group_with_models(group_name)

if isinstance(suggestions, list):
    print("\nSuggestions for reassignment with confidence scores and links to JIRA, sorted by confidence:")
    for suggestion in suggestions:
        print(f"\nTicket {suggestion['Ticket']}")
        print(f"Current Group: {suggestion['Current Group']}")
        print(f"Suggested Group: {suggestion['Suggested Group']}")
        print(f"Confidence Score: {suggestion['Confidence Score']:.2f}")
        print("Model Predictions:")
        for model_name, (pred, conf) in suggestion['Model Predictions'].items():
            print(f"  {model_name}: {pred} (confidence: {conf:.2f})")
else:
    print(suggestions)



# Example usage
group_name = "M365"
suggestions = validate_and_suggest_it_group_with_models(group_name)

if isinstance(suggestions, list):
    print("Suggestions for reassignment with confidence scores and links to JIRA, sorted by confidence:")
    for suggestion in suggestions:
        print(f"\nTicket {suggestion['Ticket']}")
        print(f"Current Group: {suggestion['Current Group']}")
        print(f"Suggested Group: {suggestion['Suggested Group']}")
        print(f"Confidence Score: {suggestion['Confidence Score']:.2f}")
        print("Model Predictions:")
        for model_name, (pred, conf) in suggestion['Model Predictions'].items():
            print(f"  {model_name}: {pred} (confidence: {conf:.2f})")
else:
    print(suggestions)
